# %%
import pandas as pd

# %%
df = pd.read_csv("house.csv")

# %%
X = df[['SqFt']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(x_train,y_train)
# Out:
# 0.7637103213912803

# %%
x_train.head(2)
# Out:
#      SqFt
# 101  2260
# 71   2160

# %%
y_train[0:2]
# Out:
# 101    123100
# 71     157600
# Name: Price, dtype: int64

# %%
df[df['SqFt']==df['SqFt'].max()]
# Out:
#     Bathrooms  Offers Brick Neighborhood  Bedrooms  SqFt   Price
# 14          3       4    No         West         4  2590  176800

# %%
model.predict([[100000]])
# Out:
# /usr/local/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([176800.])

# %%
from sklearn.tree import plot_tree, export_graphviz

# %%
export_graphviz(model,"model.dot")
# http://www.webgraphviz.com/
# paste the content of dot file in that link

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(14,20))
plot_tree(model)
plt.show()
